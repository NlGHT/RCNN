# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import csv

# %%
path = "Images"
annot = "Annotations"

# %%
for e,i in enumerate(os.listdir(annot)):
    if e < 10:
        filename = i.split(".")[0]+".jpg"
        img = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(annot,i))

       # print(df.shape)
        plt.imshow(img)
        #fileS = open(os.path.join(annot,i))
        
        with open(os.path.join(annot,i)) as csvDataFile:
            i = 0
            csvReader = csv.reader(csvDataFile)
            for row in csvReader:
                print(row)

                if(i==0):
                    i += 1
                else:
                    x1 = int(row[0])
                    y1 = int(row[1])
                    x2 = int(row[2])
                    y2 = int(row[3])
                    cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)
        plt.figure()
        plt.imshow(img)
        break
# Out:
# ['1']
# ['0', '344', '414', '407']

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
im = cv2.imread(os.path.join(path,"000000001709.jpg"))
ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = im.copy()
for i, rect in (enumerate(rects)):
    x, y, w, h = rect
#     print(x,y,w,h)
#     imOut = imOut[x:x+w,y:y+h]
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
# plt.figure()
plt.imshow(imOut)

# %%
train_images=[]
train_labels=[]

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
for e,i in enumerate(os.listdir(annot)):
    try:
        filename = str(i).split(".")[0]+".jpg"
        print(e,filename)
        image = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(annot,i))
        gtvalues=[]

        with open(os.path.join(annot,i)) as csvDataFile:
            i = 0
            csvReader = csv.reader(csvDataFile)
            for row in csvReader:
                print(row)

                if(i==0):
                    i += 1
                else:
                    x1 = int(row[0])
                    y1 = int(row[1])
                    x2 = int(row[2])
                    y2 = int(row[3])
                    gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
        ss.setBaseImage(image)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = image.copy()
        counter = 0
        falsecounter = 0
        flag = 0
        fflag = 0
        bflag = 0
        for e,result in enumerate(ssresults):
            if e < 2000 and flag == 0:
                for gtval in gtvalues:
                    x,y,w,h = result
                    iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                    print("GotHere")
                    if counter < 30:
                        if iou > 0.70:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(1)
                            counter += 1
                    else :
                        fflag =1
                    if falsecounter <30:
                        if iou < 0.3:
                            timage = imout[y:y+h,x:x+w]
                            resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                            train_images.append(resized)
                            train_labels.append(0)
                            falsecounter += 1
                    else :
                        bflag = 1
                if fflag == 1 and bflag == 1:
                    print("inside")
                    flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# g
# 385 SBU-test23.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test23.jpg
# 386 SBU-test24.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test24.jpg
# 387 SBU-test25.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test25.jpg
# 388 SBU-test26.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test26.jpg
# 389 SBU-test28.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test28.jpg
# 390 SBU-test29.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test29.jpg
# 391 SBU-test30.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test30.jpg
# 392 SBU-test31.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test31.jpg
# 393 SBU-test32.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test32.jpg
# 394 SBU-test33.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test33.jpg
# 395 SBU-test34.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test34.jpg
# 396 SBU-test35.jpg
# 'numpy.int64' object has no attribute 'split'
# error in SBU-test35.jpg
# 397 web-shadow0001.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0001.jpg
# 398 web-shadow0002.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0002.jpg
# 399 web-shadow0003.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0003.jpg
# 400 web-shadow0004.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0004.jpg
# 401 web-shadow0005.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0005.jpg
# 402 web-shadow0006.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0006.jpg
# 403 web-shadow0007.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0007.jpg
# 404 web-shadow0008.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0008.jpg
# 405 web-shadow0009.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0009.jpg
# 406 web-shadow0010.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0010.jpg
# 407 web-shadow0011.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0011.jpg
# 408 web-shadow0012.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0012.jpg
# 409 web-shadow0013.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0013.jpg
# 410 web-shadow0014.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0014.jpg
# 411 web-shadow0015.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0015.jpg
# 412 web-shadow0016.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0016.jpg
# 413 web-shadow0017.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0017.jpg
# 414 web-shadow0018.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0018.jpg
# 415 web-shadow0019.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0019.jpg
# 416 web-shadow0020.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0020.jpg
# 417 web-shadow0023.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0023.jpg
# 418 web-shadow0024.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0024.jpg
# 419 web-shadow0025.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0025.jpg
# 420 web-shadow0026.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0026.jpg
# 421 web-shadow0027.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0027.jpg
# 422 web-shadow0028.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0028.jpg
# 423 web-shadow0029.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0029.jpg
# 424 web-shadow0031.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0031.jpg
# 425 web-shadow0032.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0032.jpg
# 426 web-shadow0033.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0033.jpg
# 427 web-shadow0034.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0034.jpg
# 428 web-shadow0035.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0035.jpg
# 429 web-shadow0036.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0036.jpg
# 430 web-shadow0037.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0037.jpg
# 431 web-shadow0038.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0038.jpg
# 432 web-shadow0039.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0039.jpg
# 433 web-shadow0040.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0040.jpg
# 434 web-shadow0041.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0041.jpg
# 435 web-shadow0042.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0042.jpg
# 436 web-shadow0043.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0043.jpg
# 437 web-shadow0044.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0044.jpg
# 438 web-shadow0045.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0045.jpg
# 439 web-shadow0046.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0046.jpg
# 440 web-shadow0047.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0047.jpg
# 441 web-shadow0048.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow
jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0139.jpg
# 525 web-shadow0140.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0140.jpg
# 526 web-shadow0141.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0141.jpg
# 527 web-shadow0142.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0142.jpg
# 528 web-shadow0143.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0143.jpg
# 529 web-shadow0144.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0144.jpg
# 530 web-shadow0145.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0145.jpg
# 531 web-shadow0146.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0146.jpg
# 532 web-shadow0147.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0147.jpg
# 533 web-shadow0148.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0148.jpg
# 534 web-shadow0149.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0149.jpg
# 535 web-shadow0150.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0150.jpg
# 536 web-shadow0151.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0151.jpg
# 537 web-shadow0152.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0152.jpg
# 538 web-shadow0153.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0153.jpg
# 539 web-shadow0154.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0154.jpg
# 540 web-shadow0155.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0155.jpg
# 541 web-shadow0157.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0157.jpg
# 542 web-shadow0158.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0158.jpg
# 543 web-shadow0159.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0159.jpg
# 544 web-shadow0160.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0160.jpg
# 545 web-shadow0161.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0161.jpg
# 546 web-shadow0162.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0162.jpg
# 547 web-shadow0163.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0163.jpg
# 548 web-shadow0164.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0164.jpg
# 549 web-shadow0165.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0165.jpg
# 550 web-shadow0166.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0166.jpg
# 551 web-shadow0167.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0167.jpg
# 552 web-shadow0168.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0168.jpg
# 553 web-shadow0169.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0169.jpg
# 554 web-shadow0170.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0170.jpg
# 555 web-shadow0171.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0171.jpg
# 556 web-shadow0172.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0172.jpg
# 557 web-shadow0173.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0173.jpg
# 558 web-shadow0174.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0174.jpg
# 559 web-shadow0175.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0175.jpg
# 560 web-shadow0176.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0176.jpg
# 561 web-shadow0177.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0177.jpg
# 562 web-shadow0178.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0178.jpg
# 563 web-shadow0179.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0179.jpg
# 564 web-shadow0180-1.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0180-1.jpg
# 565 web-shadow0180-2.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0180-2.jpg
# 566 web-shadow0180-3.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0180-3.jpg
# 567 web-shadow0180-4.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0180-4.jpg
# 568 web-shadow0181.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0181.jpg
# 569 web-shadow0182.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0182.jpg
# 570 web-shadow0183.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0183.jpg
# 571 web-shadow0184.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0184.jpg
# 572 web-shadow0185.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0185.jpg
# 573 web-shadow0186.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0186.jpg
# 574 web-shadow0187.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0187.jpg
# 575 web-shadow0188.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0188.jpg
# 576 web-shadow0191.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0191.jpg
# 577 web-shadow0192.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0192.jpg
# 578 web-shadow0193.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0193.jpg
# 579 web-shadow0194.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0194.jpg
# 580 web-shadow0195.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0195.jpg
# 581 web-shadow0196.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0196.jpg
# 582 web-shadow0197.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0197.jpg
# 583 web-shadow0199.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0199.jpg
# 584 web-shadow0200.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0200.jpg
# 585 web-shadow0202.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0202.jpg
# 586 web-shadow0203-1.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0203-1.jpg
# 587 web-shadow0203-2.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0203-2.jpg
# 588 web-shadow0203-4.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0203-4.jpg
# 589 web-shadow0204-2.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0204-2.jpg
# 590 web-shadow0205.jpg
# 'numpy.int64' object has no attribute 'split'
# error in web-shadow0205.jpg
# 591 web-shadow0206.jpg
# 'numpy.int64' object has no attribute 'split'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-84977bbc709a> in <module>
#       8         for row in df.iterrows():
# ----> 9             x1 = int(row[1][0].split(" ")[0])
#      10             y1 = int(row[1][0].split(" ")[1])
#
# AttributeError: 'numpy.int64' object has no attribute 'split'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-84977bbc709a> in <module>
#      49                     flag = 1
#      50     except Exception as e:
# ---> 51         print(e)
#      52         print("error in "+filename)
#      53         continue
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
X_new.shape
# Out:
# (0,)

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16

# %%
vggmodel = VGG16(weights='imagenet', include_top=True)
vggmodel.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 27s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
# Out:
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x0000021B60568640>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B605AFFD0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B605CC340>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000021B605CCA00>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B60636BB0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B60641070>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000021B606468E0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B6064CAF0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B60651970>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B60657A00>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000021B6065E6D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B60665AF0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B6066D940>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000021B6066D850>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000021B6065E4F0>

# %%
X= vggmodel.layers[-2].output

# %%
predictions = Dense(2, activation="softmax")(X)

# %%
model_final = Model(input = vggmodel.input, output = predictions)

# %%
from keras.optimizers import Adam
opt = Adam(lr=0.0001)

# %%
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])

# %%
model_final.summary()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')

# %%
hist = model_final.fit_generator(generator= traindata, steps_per_epoch= 10, epochs= 1000, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
im = X_test[1600]
plt.imshow(im)
img = np.expand_dims(im, axis=0)
out= model_final.predict(img)
if out[0][0] > out[0][1]:
    print("plane")
else:
    print("not plane")

# %%
z=0
for e,i in enumerate(os.listdir(path)):
    if i.startswith("4"):
        z += 1
        img = cv2.imread(os.path.join(path,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = img.copy()
        for e,result in enumerate(ssresults):
            if e < 2000:
                x,y,w,h = result
                timage = imout[y:y+h,x:x+w]
                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                img = np.expand_dims(resized, axis=0)
                out= model_final.predict(img)
                if out[0][0] > 0.65:
                    cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        plt.figure()
        plt.imshow(imout)
